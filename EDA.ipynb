# %%
# import kagglehub

# data = kagglehub.dataset_download("arjunbhasin2013/ccdata")

# print(data)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# # Exploring Data
#
#
#
#    - CUSTID : Identification of Credit Card holder (Categorical)
#    - BALANCE : Balance amount left in their account to make purchases (
#    - BALANCEFREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
#    - PURCHASES : Amount of purchases made from account
#    - ONEOFFPURCHASES : Maximum purchase amount done in one-go
#    - INSTALLMENTSPURCHASES : Amount of purchase done in installment
#    - CASHADVANCE : Cash in advance given by the user
#    - PURCHASESFREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
#    - ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
#    - PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
#    - CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
#    - CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
#    - PURCHASESTRX : Numbe of purchase transactions made
#    - CREDITLIMIT : Limit of Credit Card for user
#    - PAYMENTS : Amount of Payment done by user
#    - MINIMUM_PAYMENTS : Minimum amount of payments made by user
#    - PRCFULLPAYMENT : Percent of full payment paid by user
#    - TENURE : Tenure of credit card service for user

# %%
# define numerical and categorical features

numerical_features = [col for col in df.columns if df[col].dtype != 'O']
categorical_features = [col for col in df.columns if df[col].dtype == "O"]

# %%
print("numerical_features =>",numerical_features)
print("\n categorical_features =>", categorical_features)
# Out:
# numerical_features => ['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']
#
#  categorical_features => ['CUST_ID']

# %%
print(f"we have {len(numerical_features)} numerical_features")
print(f"we have {len(categorical_features) } categorical_feature")
# Out:
# we have 17 numerical_features
# we have 1 categorical_features

# %% [markdown]
# Univariate Analysis

# %%
plt.rcParams["figure.figsize"] = (15,25)
plt.suptitle("Univariate Analysis of Numerical Features", fontsize=20, fontweight="bold", alpha=0.8, y=1 )

for i, col in enumerate(numerical_features):
    ax = plt.subplot(6,3,i+1)
    sns.histplot(data=df, x=col, color="blue", ax=ax, kde=True)
    plt.xlabel(numerical_features[i])
    plt.tight_layout()

# %% [markdown]
# # Multivariate Analysis

# %%
df.corr(numeric_only=True)
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
# #### Purchase and one_off purchases are highly correlated
# #### Other feature don't have much collinearity

# %% [markdown]
# #### Checking Null Values

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#  Minimum payment column has 313 missing values
# Credit limit has 1 missing values
# Missing values can be handled in feature engineering.

# %%
continuous_features = [feature for feature in numerical_features if df[feature].nunique() >= 20]
print(f"Continuous features: {continuous_features}, \n Number of Continuous features:", len(continuous_features))
# Out:
# Continuous features: ['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT'],
#  Number of Continuous features: 16

# %%
for i in numerical_features:
    if i not in continuous_features:
        print(i)
# Out:
# TENURE

# %%
df["TENURE"].value_counts()
# Out:
# TENURE
# 12    7584
# 11     365
# 10     236
# 6      204
# 8      196
# 7      190
# 9      175
# Name: count, dtype: int64

# %% [markdown]
# - There are missing values in the 2 columns
# - Many of the skewed columns can be transformed
# - In the Categorical column, which is CustomerID we can remove it in data cleaning as it won't be required for the model

# %% [markdown]
# #### Visualization

# %%
sns.set(style="whitegrid")

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df["BALANCE"], kde=True, color="b", bins=100)
plt.title("Balance Distribution", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlabel("Balance in $", weight="bold", fontsize=16)
plt.show()

# %% [markdown]
# - There are high numbers of credit card with zero balance, this could be due to people are holding what is called zero balance card

# %%
# Balance Frquency

plt.subplots(figsize=(14,7))
sns.histplot(data=df, x="BALANCE_FREQUENCY", bins=10, kde=True, color="b")
plt.title("Balance Frquency", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlabel("Balance Frequency (Range=0 and 1)", weight="bold", fontsize=16)
plt.show()

# %% [markdown]
# - As per balance frequency 1 means the balance is updated frequently and 0 is not frequently updated
# - As per chart many people get their balance frequently updated

# %%
# Purchase Count

plt.subplots(figsize=(14,7))
sns.histplot(data=df, x="PURCHASES", bins=20)
plt.xlabel("Purchase Amount", weight="bold", fontsize=16)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlim(-1000, 20000)
plt.show()

# %% [markdown]
# - From the chart its clear theat many people dont purchase
# - Most purchase spend anywhere from 0 dollars to 2500 dollars

# %%
# Type of Purchases
plt.subplot(1,2,1)
sns.histplot(df["ONEOFF_PURCHASES"], kde=True, color="green")
plt.title("Distribution of One Off Purchase", fontsize=20)
plt.xlabel("Amount")

plt.subplot(1,2,2)
sns.histplot(df["INSTALLMENTS_PURCHASES"], color="red")
plt.title("Distribution of Installment Purchase", fontsize=20)
plt.xlabel("Amount")
plt.show()

# %%
continuous_features
# Out:
# ['BALANCE',
#  'BALANCE_FREQUENCY',
#  'PURCHASES',
#  'ONEOFF_PURCHASES',
#  'INSTALLMENTS_PURCHASES',
#  'CASH_ADVANCE',
#  'PURCHASES_FREQUENCY',
#  'ONEOFF_PURCHASES_FREQUENCY',
#  'PURCHASES_INSTALLMENTS_FREQUENCY',
#  'CASH_ADVANCE_FREQUENCY',
#  'CASH_ADVANCE_TRX',
#  'PURCHASES_TRX',
#  'CREDIT_LIMIT',
#  'PAYMENTS',
#  'MINIMUM_PAYMENTS',
#  'PRC_FULL_PAYMENT']

# %%
# Credit Report

plt.subplots(figsize=(12,15))
cols = ["PURCHASES", "BALANCE", "ONEOFF_PURCHASES", "INSTALLMENTS_PURCHASES"]
for i in range(len(cols)):
    plt.subplot(2,2,i+1)
    sns.scatterplot(data=df, x=cols[i], y="CREDIT_LIMIT", color="b")
    plt.title(f"Credit Limit And {cols[i]}", fontsize=14)
    # plt.grid(False)
    plt.xlabel(cols[i])
    plt.ylabel("Credit Limit")

# %% [markdown]
# - PURCHASES and BALANCE has positive correlation with credit limit
# - Credit limit increases as balance increases, as people owes more to bank their credit scores incresae which in turn increases their credit limit
# - As Purchases increase Credit Limit also increases

# %%
# Frequency

cols = ['BALANCE_FREQUENCY','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY',
      'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY']
plt.subplots(figsize=(12,15))

for i in range(len(cols)):
    plt.subplot(3,2, i+1)
    sns.violinplot(data=df, y=cols[i], color="c", orient="v")
    plt.title(cols[i], fontsize=12)
    plt.xlabel(cols[i])
    plt.tight_layout()

# %%
# Transactions

cols = ["PURCHASES_TRX", "CASH_ADVANCE_TRX"]
for i in range(len(cols)):
    plt.subplot(1,2, i+1)
    sns.boxenplot(data=df, y=cols[i])
    plt.title(cols[i], weight="bold")
    plt.xlabel(cols[i])

# %% [markdown]
# - People make very less purchase transaction and look like people use it for credit score
# - Cash paid in advance is lesser than purchase transaction, as people will build up the balance and pay them in single transaction

# %%
# Tenure

plt.subplots(figsize=(14,7))
sns.countplot(data=df, x="TENURE", ec="black")
plt.title("TENURE choosen by Customers", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("TENURE Months (0-12 months)", weight="bold", fontsize=16)
plt.show()

# %%
df["TENURE"].value_counts()
# Out:
# TENURE
# 12    7584
# 11     365
# 10     236
# 6      204
# 8      196
# 7      190
# 9      175
# Name: count, dtype: int64

# %% [markdown]
# - Tenure is the repayment period of the cards, ranging from 6-12 months. Most of the cards are 12 months cards
# - Which means people take service for 12 months

# %%
# Payments

plt.subplots(figsize=(11,7))
sns.set_style("darkgrid")
sns.regplot(x=df["PAYMENTS"], y=df["PURCHASES"], color="g")
plt.title("Payments vs Purchases", fontsize=14)
plt.show()

# %% [markdown]
# - There is a positive correlation between Payments and Purchases

# %%
# Purchases of full payment
sns.barplot(y=df["PRC_FULL_PAYMENT"], x=df["TENURE"], palette="bright", hue=df["TENURE"])
plt.title("Percentage of full Payment done", size=15)
plt.xlabel("Tenure in Months", size=20)
plt.show()

# %% [markdown]
# - As per above chart people who opted for 6 moths EMI tenure has repaid more
# - As per months increase people repay less amount
